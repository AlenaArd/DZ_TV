# %%
Задание_1.

Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. 
Используя уровень значимости 0.025 и правостороннюю критическую область, проверить данную гипотезу при условии, 
что в выборке из 100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 мм.

# %%
Утверждается, что шарики для подшипников, изготовленные автоматическим
станком, имеют средний диаметр d =17 мм. Используя односторонний критерий с α = 0.025 , 
проверить эту гипотезу, если в выборке из n =100 шариков средний диаметр
оказался равным 17.5 мм, а дисперсия известна и равна D(X)=𝜎**2 =4 мм, поэтому(среднее квадратичное) 𝜎 =2.
РЕШЕНИЕ.
Нулевая гипотеза: H(0) : a=17 . Альтернативная гипотеза (односторонняя) H(1) : Xcр.=17.5 = >
Вычисляем наблюдаемое значение критерия Uнаб.=(Xcр.-a)*n**0.5/𝜎
(17.5-17)*10/2=2.5
Чтобы найти критическую область нужно отыскать критическое значение. Ф(u)= (1-2α)/2  
где α – выбранный уровень значимости, Ф(u)  – старая знакомая функция Лапласа.
По таблице функции Лапласа найдем критическую точку для односторонней области.
В нашем случае Ф(Uкр.)= (1-0.05)/2 = 0.475 из таблицы найдем Uкр.=1.96
 |Uнаб.|>Uкр.
# !!!_Получается гипотеза H(1) -отвергается.

# %%
Задача_2
Известно, что генеральная совоĸупность распределена нормально с известным
средним ĸвадратичесĸим отĸлонением 16. Найти доверительный интервал для оценĸи
математичесĸого ожидания a с надежностью 0.95, если выборочное среднее равно 80,
а объём равен 256

# %%
𝜎 =16, n=256, Xcр.=80, 1−𝛼=0.95=p
Выборочная средняя – это точечная оценка неизвестной нам генеральной средней . 
И по условию, требуется найти интервал , которой с вероятностью  накроет истинное значение .
Предполагая, что случайная величина  𝑋  распределена нормально, 
построим доверительный интервал для  𝑀(𝑋)  с доверительной вероятностью 0,95. Для этого воспользуемся t-распределением.
Найдём среднее и несмещённую оценку для среднего квадратического отклонения:
      𝑡1−𝛼/2,𝑛−1  — квантиль, выбранный из таблицы квантилей t-распределения = 1.9840
        Xcр.- 𝑡1−𝛼/2,𝑛−1⋅𝜎𝑋√n<𝑀(𝑋)< Xcр.+ 𝑡1−𝛼/2,𝑛−1⋅𝜎𝑋√n
    Вычислим доверительный интервал:

# %%
import numpy as np
x=80
t=1.9840
n=256
s=16
(x - t * s / np.sqrt(n), x + t * s / np.sqrt(n))
# Out:
# (78.016, 81.984)

# %%
Задача_3
Продавец утверждает, что средний вес пачĸи печенья составляет 200 г. Из партии
извлечена выборĸа из 10 пачеĸ. Вес ĸаждой пачĸи составляет:
202, 203, 199, 197, 195, 201, 200, 204, 194, 190
Известно, что их веса распределены нормально. Верно ли утверждение продавца,
если учитывать, что уровень значимости равен 1%?

# %%
Продавец утверждает, что средний вес пачĸи печенья составляет 200 г, m = 200. 
Уровень значимости равен 1% α = 0.01 , 
n =10. Выборка weight = [202, 203, 199, 197, 195, 201, 200, 204, 194, 190]
РЕШЕНИЕ. Найдем среднее значение выборки и среднее кв.отклонение

# %%
weight = np.array([202, 203, 199, 197, 195, 201, 200, 204, 194, 190])
m = weight.mean()
s = weight.std(ddof=1)
print(m, s)
# Out:
# 198.5 4.453463071962462

# %%
#выбранный из таблицы квантилей t-распределения
t = 2.2622
n=10
(m - t * s / np.sqrt(n), m + t * s / np.sqrt(n))
# Out:
# (195.31412410798328, 201.68587589201672)

# %%
Утверждение продавца верно! 200 г попадает в доверительный интервал))
